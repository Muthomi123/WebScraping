# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://www.premierleague.com/tables'
page=requests.get(url)
soup=BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" name="twitter:title"/>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" property="og:title"/>
# <title>Premier League Table, Form Guide &amp; Season Archives</title>
# <!-- Designed and built by Pulselive - www.pulselive.com -->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script>
# 		dataLayer = [];
#         window.RESOURCE_VERSION_REBRAND = 'rebrand/v7.142.1';
# 		window.RESOURCE_VERSION = 'rebrand/v7.142.1';
# 		window.BASE_RESOURCE_URL = 'https://www.premierleague.com/resources';
# 	</script>
# <!--[if gt IE 8]><!-->
# <!--<link rel="stylesheet" href="https://www.premierleague.com/resources/rebrand/v7.142.1/styles/badge-abbreviations.css">-->
# ...

# %%
Table=soup.find_all('table')[0]

# %%
Table
# Out:
# <table>
# <summary class="visuallyHidden">This table charts the Premier League teams</summary>
# <thead>
# <tr>
# <th class="league-table__pos-header" scope="col">
# <div class="league-table__thFull thFull">Position</div>
# <div class="league-table__thShort thShort">Pos</div>
# </th>
# <th class="league-table__team-header" scope="col">Club</th>
# <th scope="col">
# <div class="league-table__thFull thFull">Played</div>
# <div class="league-table__thShort thShort">Pl</div>
# </th>
# <th scope="col">
# <div class="league-table__thFull thFull">Won</div>
# <div class="league-table__thShort thShort">W</div>
# </th>
# <th scope="col">
# <div class="league-table__thFull thFull">Drawn</div>
# <div class="league-table__thShort thShort">D</div>
# </th>
# <th scope="col">
# <div class="league-table__thFull thFull">Lost</div>
# <div class="league-table__thShort thShort">L</div>
# </th>
# <th class="hideSmall" scope="col"><abbr title="Goals For">GF</abbr></th>
# ...

# %%
Table_Headers=Table.find_all('th')[0:10]

# %%
Table_Headers
# Out:
# [<th class="league-table__pos-header" scope="col">
#  <div class="league-table__thFull thFull">Position</div>
#  <div class="league-table__thShort thShort">Pos</div>
#  </th>,
#  <th class="league-table__team-header" scope="col">Club</th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Played</div>
#  <div class="league-table__thShort thShort">Pl</div>
#  </th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Won</div>
#  <div class="league-table__thShort thShort">W</div>
#  </th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Drawn</div>
#  <div class="league-table__thShort thShort">D</div>
#  </th>,
#  <th scope="col">
#  <div class="league-table__thFull thFull">Lost</div>
#  <div class="league-table__thShort thShort">L</div>
#  </th>,
#  <th class="hideSmall" scope="col"><abbr title="Goals For">GF</abbr></th>,
#  <th class="hideSmall" scope="col"><abbr title="Goals Against">GA</abbr></th>,
# ...

# %%
Headers=[header.text.strip() for header in Table_Headers]
print(Headers)
# Out:
# ['Position\nPos', 'Club', 'Played\nPl', 'Won\nW', 'Drawn\nD', 'Lost\nL', 'GF', 'GA', 'GD', 'Points\nPts']

# %%
Table.find_all(class_='tableDark')
# Out:
# [<tr class="tableDark" data-compseason="578" data-filtered-entry-size="20" data-filtered-table-row="1" data-filtered-table-row-abbr="1" data-filtered-table-row-name="Arsenal" data-filtered-table-row-opta="t3" data-position="1">
#  <td class="league-table__pos pos button-tooltip" id="Tooltip" tabindex="0">
#  <span class="league-table__value value">1</span>
#  <span class="league-table__movement none">
#  <span class="league-table__tooltip-container tooltipContainer tooltip-left" role="tooltip">
#  <span class="league-table__tooltip-content tooltip-content">
#                              Previous Position
#
#                              <span class="league-table__result-highlight">
#                                  1
#                              </span>
#  </span>
#  </span>
#  </span>
#  </td>
#  <td class="league-table__team team" scope="row">
#  <a href="/clubs/1/Arsenal/overview">
# ...

# %%
Table.find_all(class_='league-table__team-name league-table__team-name--long long')
# Out:
# [<span class="league-table__team-name league-table__team-name--long long">Arsenal</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Liverpool</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Manchester City</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Aston Villa</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Tottenham Hotspur</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Manchester United</span>,
#  <span class="league-table__team-name league-table__team-name--long long">West Ham United</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Brighton and Hove Albion</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Wolverhampton Wanderers</span>,
# ...

# %%
Teams=Table.find_all(class_='league-table__team-name league-table__team-name--long long')

# %%
Teams
# Out:
# [<span class="league-table__team-name league-table__team-name--long long">Arsenal</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Liverpool</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Manchester City</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Aston Villa</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Tottenham Hotspur</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Manchester United</span>,
#  <span class="league-table__team-name league-table__team-name--long long">West Ham United</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Brighton and Hove Albion</span>,
#  <span class="league-table__team-name league-table__team-name--long long">Wolverhampton Wanderers</span>,
# ...

# %%
Premier_league_Teams=[team.text for team in Teams]
print(Premier_league_Teams)
# Out:
# ['Arsenal', 'Liverpool', 'Manchester City', 'Aston Villa', 'Tottenham Hotspur', 'Manchester United', 'West Ham United', 'Brighton and Hove Albion', 'Wolverhampton Wanderers', 'Newcastle United', 'Chelsea', 'Fulham', 'Bournemouth', 'Crystal Palace', 'Brentford', 'Everton', 'Luton Town', 'Nottingham Forest', 'Burnley', 'Sheffield United']

# %%
Clubs=Premier_league_Teams
for club in Clubs:
    print(club)
# Out:
# Arsenal
# Liverpool
# Manchester City
# Aston Villa
# Tottenham Hotspur
# Manchester United
# West Ham United
# Brighton and Hove Albion
# Wolverhampton Wanderers
# Newcastle United
# Chelsea
# Fulham
# Bournemouth
# Crystal Palace
# Brentford
# Everton
# Luton Town
# Nottingham Forest
# Burnley
# Sheffield United
