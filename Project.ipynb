# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Name
def get_ProductName(soup):
    try:
        # Outer Tag Object
        Product_Name = soup.find(class_="-fs20 -pts -pbxs")
        
        # Inner NavigatableString Object
        ProductName_value = Product_Name.text

        # Title as a string value
        ProductName_string = ProductName_value.strip()

    except AttributeError:
        ProductName_string = ""

    return ProductName_string

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.find(class_="-b -ubpt -tal -fs24 -prxs").string.strip()

    except AttributeError:
        price = ""

    return price

# Function to extract old price
def get_Oldprice(soup):
    try:
        price = soup.find(class_="-tal -gy5 -lthr -fs16 -pvxs -ubpt").string.strip()

    except AttributeError:
        price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):
    try:
       rating_div = soup.find("div", class_="stars _m _al")
       rating = rating_div.text.strip()

    except AttributeError:
        rating = ""    

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    review_count = ""
    try:
        verified_ratings_link = soup.find("a", class_="-plxs _more")
        if verified_ratings_link:
            review_count = verified_ratings_link.text.strip()

    except AttributeError:
        pass

    return review_count


if __name__ == '__main__':
    HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'}
    
    URL="https://www.jumia.co.ke/smart-tvs-2282/?page=2#catalog-listing"
    
    webpage = requests.get(URL, headers=HEADERS)
    
    soup = BeautifulSoup(webpage.content, "html.parser")
    
    links = soup.find_all("a", attrs={'class': 'core'})
    
    links_list = []
    
    for link in links:
        links_list.append(link.get('href'))
    
    d = {"Product Name":[], "Product Price":[], "Price Before Discount":[], "rating":[], "review count":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://jumia.co.ke" + link, headers=HEADERS, allow_redirects=True)
    
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")
         
        # Function calls to display all necessary product information
        d['Product Name'].append(get_ProductName(new_soup))
        d['Product Price'].append(get_price(new_soup))
        d['Price Before Discount'].append(get_Oldprice(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['review count'].append(get_review_count(new_soup))

# %%
jumia_df = pd.DataFrame.from_dict(d)
jumia_df['Product Name'].replace('', np.nan, inplace=True)
jumia_df = jumia_df.dropna(subset=['Product Name'])
jumia_df.to_csv("jumia_data.csv", header=True, index=False)

# %%
jumia_df
# Out:
#                                          Product Name Product Price  \
# 0   Hisense 43A6K 43 inch 4K UHD Smart TV (2YRs WRTY)    KSh 37,199
# 1   TCL 43S5400A,43" Inch Smart  ANDROID TV BT Ica...    KSh 34,490
# 2   Vitron 32" Inch Smart Android Tv,Frameless, Ne...    KSh 14,999
# 3   Gld 43" Smart Frameless Full HD LED Television...    KSh 19,497
# 4   Hifinit 43'' Inch Android Smart FHD NETFLIX YO...    KSh 21,990
# 5   Infinix X1 32" Inch Frameless Bluetooth Smart ...    KSh 15,999
# 6   Gld 43" inch FHD Frameless Smart/Android TV,BL...    KSh 22,799
# 7   Skyworth 32STD6500-32"Inch Smart Android TV Ne...    KSh 19,699
# 8   Vision Plus  43" Inch Television Bluetooth-Ena...    KSh 25,990
# 9   Vitron 32" Inch Smart Android Tv,Frameless, Ne...    KSh 13,999
# 10  Vitron Frameless 32" Inch Smart Android TV Net...    KSh 13,699
# 11  Vitron HTC3200S,32"Inch Frameless Smart Androi...    KSh 13,695
# 12       Hisense 43A4K Smart 43 inches TV (2YRs WRTY)    KSh 32,799
# 13  Gld 32 Inch Frameless Smart-Digital Android TV...    KSh 14,390
# 14  Vitron HTC5568S,55" inch FRAMELESS- 4K ULTRA H...    KSh 46,990
# 15  Vitron 4388FS 43"Inch Frameless FULLHD Smart A...    KSh 21,895
# 16  Vitron FHD 43"inch Bluetooth enabled Frameless...    KSh 22,999
# 17  Gld 32 Inches,FRAMELESS, BLUETOOTH, SMART ANDR...    KSh 13,999
# 18  Vitron 32- Inch Frameless Smart Android TV,Net...    KSh 14,599
# 19  MG Frameless, Smart Android 32inch TV + 2Free ...    KSh 14,299
# 20  Gld 43" inch TV Smart Android TV Bluetooth Con...    KSh 22,995
# 21  Vitron HTC3218 32” Inch,FRAMELESS LED DIGITAL ...    KSh 12,990
# 22  Vitron HTC4068FS,40"Inches Frameless Televisio...    KSh 20,999
# 23  Vitron HTC3200S,Frameless 32" Inch Television ...    KSh 14,595
# 24  Hisense 43" Inch FRAMELESS SMART TV,BLUETOOTH,...    KSh 39,999
# 25  Gld 32"inch Frameless SmartAndroid TV Appstore...    KSh 14,685
# 26                       Hisense 43" A4K Series Smart    KSh 33,499
# 27  Vitron HTC4068FS, 40"inch Frameless Television...    KSh 20,699
# 28  TCL 43S5400- 43" inch FHD,Google TV,Android OS...    KSh 35,999
# 29  Amtec 32R1S,32 Inch Bluetooth TV  SMART Androi...    KSh 13,495
# 30  Hisense A4- 32" Inch Frameless FHD SMART TV ,N...    KSh 20,990
# 31  Vitron HD 32inch TV Smart LED Android 11-TV,Ap...    KSh 14,899
# 32  Gld 32" Inch SMART-DIGITAL ANDROID TV, HDMI, N...    KSh 13,599
# 33  Amtec 43L12,43" Inch BLUETOOTH SMART Televisio...    KSh 21,699
# 34  Vitron HTC4388FS,43''SMART TV Android Frameles...    KSh 22,495
# 35  Vitron HTC3200S,32" Inch TV Television Framele...    KSh 13,685
# 36  Royal Frameless, 43" Smart TV USB HDMI+ FREE T...    KSh 23,895
# 37  Hisense 32A4H 32" Smart TV Netflix,Youtube,VID...    KSh 20,699
# 38  Vision Plus 43" Inch Television Bluetooth-Enab...    KSh 24,899
# 39  Amtec 43L12 43" Inch TV Smart Android TV Bluet...    KSh 22,895
#
#    Price Before Discount        rating            review count
# 0             KSh 43,000    5 out of 5     (1 verified rating)
# 1             KSh 42,999  4.4 out of 5    (8 verified ratings)
# 2             KSh 21,300  4.2 out of 5   (18 verified ratings)
# 3             KSh 30,000    4 out of 5     (1 verified rating)
# 4             KSh 37,200  4.3 out of 5    (4 verified ratings)
# 5             KSh 30,000  4.2 out of 5   (51 verified ratings)
# 6             KSh 40,000    5 out of 5     (1 verified rating)
# 7             KSh 30,000  4.7 out of 5   (35 verified ratings)
# 8             KSh 50,000  4.2 out of 5   (13 verified ratings)
# 9             KSh 27,200  4.3 out of 5   (46 verified ratings)
# 10            KSh 26,000  4.3 out of 5    (3 verified ratings)
# 11            KSh 20,000    4 out of 5    (2 verified ratings)
# 12            KSh 36,000  4.5 out of 5    (2 verified ratings)
# 13            KSh 28,000    5 out of 5    (3 verified ratings)
# 14            KSh 80,000    5 out of 5     (1 verified rating)
# 15            KSh 30,000  3.5 out of 5    (4 verified ratings)
# 16                          0 out of 5  (No ratings available)
# 17            KSh 20,000  4.4 out of 5    (7 verified ratings)
# 18            KSh 26,000  2.3 out of 5    (3 verified ratings)
# 19            KSh 20,800  4.4 out of 5    (5 verified ratings)
# 20            KSh 28,000  4.5 out of 5    (4 verified ratings)
# 21            KSh 22,000  3.5 out of 5   (24 verified ratings)
# 22            KSh 25,000  4.1 out of 5  (188 verified ratings)
# 23            KSh 19,500  4.1 out of 5   (94 verified ratings)
# 24            KSh 78,000  3.8 out of 5    (9 verified ratings)
# 25            KSh 20,000  4.1 out of 5   (16 verified ratings)
# 26            KSh 45,000    0 out of 5  (No ratings available)
# 27            KSh 32,299  4.3 out of 5   (85 verified ratings)
# 28            KSh 60,000    5 out of 5     (1 verified rating)
# 29            KSh 20,000  3.9 out of 5   (16 verified ratings)
# 30            KSh 38,000    4 out of 5     (1 verified rating)
# 31                          3 out of 5     (1 verified rating)
# 32            KSh 26,000    5 out of 5     (1 verified rating)
# 33            KSh 30,000  4.4 out of 5    (8 verified ratings)
# 34            KSh 30,000  4.3 out of 5  (302 verified ratings)
# 35            KSh 25,000    4 out of 5     (1 verified rating)
# 36            KSh 30,000  4.8 out of 5   (16 verified ratings)
# 37            KSh 30,000  4.7 out of 5    (3 verified ratings)
# 38            KSh 28,999    0 out of 5  (No ratings available)
# 39            KSh 30,000  3.6 out of 5    (5 verified ratings)
